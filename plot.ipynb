# %%
import matplotlib.pyplot as plt
from src.utils import plot_all_training_on_all_splits

# %%
plot_all_training_on_all_splits(train_history_folder ="train_history", 
                                save_image_dir="train_history_plots")
